# %%
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import MathsUtilities as MUte
import matplotlib.dates as mdates
# %matplotlib inline

# %%
ResidueTestNames = ['StovN0.5High.csv','StovN1.6High.csv','StovN3.5High.csv','StovN4.7High.csv','StovN0.5Low.csv','StovN1.6Low.csv','StovN3.5Low.csv','StovN4.7Low.csv']

# %%
ResidueTests = []
for t in ResidueTestNames:
    rt = pd.read_csv('C:\\GitHubRepos\\SVSModelBuildDeploy\\TestModel\\TestConsole\\bin\\Debug\\net6.0\\OutputFiles\\'+t,index_col="Date")
    ResidueTests.append(rt)
AllResidueTests = pd.concat(ResidueTests,axis=0,keys=ResidueTestNames)

# %%
Graph = plt.figure()
ax = Graph.add_subplot(1,1,1)
for t in ResidueTestNames:
    plt.plot(AllResidueTests.loc[t,'ResidueN'].cumsum())

# %%
AllResidueTests)
# Out:
# <Axes: xlabel='None,Date'>

# %%
test = pd.read_csv('C:\\GitHubRepos\\SVSModelBuildDeploy\\TestModel\\TestConsole\\bin\\Debug\\net6.0\\OutputFiles\\'+ResidueTestNames[0],index_col="Date")

# %%
test
# Out:
#                         SoilMineralN   UptakeN   ResidueN   SoilOMN  \
# Date
# 24/01/2023 12:00:00 am     50.915656  0.201064   0.000000  1.116720
# 25/01/2023 12:00:00 am     40.919047  0.193349 -10.997147  1.193888
# 26/01/2023 12:00:00 am     21.186887  0.000000 -20.971381  1.239221
# 27/01/2023 12:00:00 am      7.450122  0.000000 -14.887764  1.150999
# 28/01/2023 12:00:00 am     -3.172456  0.000000 -11.699685  1.077108
# 29/01/2023 12:00:00 am    -16.157518  0.000000 -14.092232  1.107169
# 30/01/2023 12:00:00 am    -25.742442  0.000000 -10.681332  1.096408
# 31/01/2023 12:00:00 am    -34.164649  0.000000  -9.512444  1.090236
# 1/02/2023 12:00:00 am     -43.683867  0.000000 -10.646181  1.126963
# 2/02/2023 12:00:00 am     -46.088137  0.000000  -3.457120  1.052850
# 3/02/2023 12:00:00 am     -47.875007  0.000000  -2.773300  0.986429
# 4/02/2023 12:00:00 am     -52.236091  0.000000  -5.337359  0.976275
# 5/02/2023 12:00:00 am     -51.541815  0.000000  -0.200144  0.894421
# ...
